# %% [markdown]
# <a href="https://colab.research.google.com/github/ozmarie/pdc-assignments/blob/main/ForestFire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python firestarter.py
# Out:
# python3: can't open file '/content/firestarter.py': [Errno 2] No such file or directory

# %%
# !pip install mpi4py
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 49.4 MB/s eta 0:00:00
# ...

# %%
# !mpirun --allow-run-as-root --oversubscribe -n 4 python3 firestarter.py
# Out:
# Probability of fire spreading, Average percent burned, Iterations
#
# Trial group 0. Ramk: 2. Time: 0.00015735626220703125
# Probability of fire spreading, Average percent burned, Iterations
#
# Trial group 0. Ramk: 3. Time: 0.0001461505889892578
# Probability of fire spreading, Average percent burned, Iterations
#
# Trial group 0. Ramk: 1. Time: 0.00014162063598632812
# Probability of fire spreading, Average percent burned, Iterations
#
# Trial group 0. Ramk: 0. Time: 0.00016069412231445312
# Trial group 1. Ramk: 3. Time: 6.96579384803772
# Trial group 1. Ramk: 2. Time: 7.0309858322143555
# Trial group 1. Ramk: 0. Time: 7.053339719772339
# Trial group 1. Ramk: 1. Time: 7.1657326221466064
# Trial group 2. Ramk: 3. Time: 12.85201358795166
# Trial group 2. Ramk: 2. Time: 13.31773591041565
# Trial group 2. Ramk: 1. Time: 13.568547487258911
# Trial group 2. Ramk: 0. Time: 13.66681981086731
# Trial group 3. Ramk: 3. Time: 19.9958438873291
# Trial group 3. Ramk: 2. Time: 20.29566717147827
# ...
